# %%
import numpy as np
arr = np.array([[3, 4, 5], [6, 7, 8], [1, 2, 0]])

# %%
arr
# Out:
# array([[3, 4, 5],
#        [6, 7, 8],
#        [1, 2, 0]])

# %%
arr.shape
# Out:
# (3, 3)

# %%
ada = np.array([1.1, 2.2, 3.3, 4.4])

# %%
ada
# Out:
# array([1.1, 2.2, 3.3, 4.4])

# %%
x = ada.astype('int64')

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
ind = np.array([1, 2, 3, 4, 5, 6])
ind
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
ind[[1,3,5]]
# Out:
# array([2, 4, 6])

# %%
change = arr.reshape(1,9)

# %%
change
# Out:
# array([[3, 4, 5, 6, 7, 8, 1, 2, 0]])

# %%
new = np.array([34, 45, 56, 67, 78, 12, 23, 89])

# %%
new
# Out:
# array([34, 45, 56, 67, 78, 12, 23, 89])

# %%
new[new > 50]
# Out:
# array([56, 67, 78, 89])

# %%
x = np.linspace(0,1,5).reshape(1,5)

# %%
x.shape
# Out:
# (1, 5)
