# %%
import numpy as np
arr = np.array([1,2,3,4,5,6,78,9])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6., 78.,  9.])

# %%
arr.nbytes
# Out:
# 64

# %%
np.linespace(0,1,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.linespace(0,1,5)
#
# NameError: name 'np' is not defined
