# %%
import pandas as pd

# %%
df = pd.read_csv("datacleaning.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   NaN        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 6  Charlie   NaN        Delhi      M    charlie@example  2021-07-20

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False  False  False   False  False      False
# 2  False   True  False   False  False      False
# 3  False  False  False   False  False      False
# 4   True  False  False   False  False       True
# 5  False  False  False   False  False      False
# 6  False   True  False   False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          2
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.dropna()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1    Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 3  David  22.0       Mumbai      M  david@example.com  2019-11-12
# 5  Alice  25.0     New York      F  alice@example.com  2021-05-01

# %%
df.dropna(axis=1)
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1  Los Angeles      M    bob@example.com
# 2        Delhi      M    charlie@example
# 3       Mumbai      M  david@example.com
# 4        Delhi      F     eve@domain.com
# 5     New York      F  alice@example.com
# 6        Delhi      M    charlie@example

# %%
df.fillna(0)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   0.0        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4        0  28.0        Delhi      F     eve@domain.com           0
# 5    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 6  Charlie   0.0        Delhi      M    charlie@example  2021-07-20

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    26.0
# 3    22.0
# 4    28.0
# 5    25.0
# 6    26.0
# Name: Age, dtype: float64

# %%
df.ffill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie  30.0        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4    David  28.0        Delhi      F     eve@domain.com  2019-11-12
# 5    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 6  Charlie  25.0        Delhi      M    charlie@example  2021-07-20

# %%
df.bfill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie  22.0        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4    Alice  28.0        Delhi      F     eve@domain.com  2021-05-01
# 5    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 6  Charlie   NaN        Delhi      M    charlie@example  2021-07-20

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   NaN        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 6  Charlie   NaN        Delhi      M    charlie@example  2021-07-20

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   NaN        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.duplicated(subset=["Name", "Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
df["Name"].str.lower()
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      david
# 4        NaN
# 5      alice
# 6    charlie
# Name: Name, dtype: object

# %%
df["City"].str.contains("delhi", case=False)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: City, dtype: bool

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [bob, example.com]
# 2      [charlie, example]
# 3    [david, example.com]
# 4       [eve, domain.com]
# 5    [alice, example.com]
# 6      [charlie, example]
# Name: Email, dtype: object

# %%
df2 = df.dropna().copy()

# %%
df2["Age"] = df2["Age"].astype(int)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  2021-05-01
# 1    Bob   30  Los Angeles      M    bob@example.com  2020-06-15
# 3  David   22       Mumbai      M  david@example.com  2019-11-12
# 5  Alice   25     New York      F  alice@example.com  2021-05-01

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       4 non-null      object
#  1   Age        4 non-null      int64
#  2   City       4 non-null      object
#  3   Gender     4 non-null      object
#  4   Email      4 non-null      object
#  5   Join Date  4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 224.0+ bytes

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 1      Bob  30.0  Los Angeles      M    bob@example.com  2020-06-15
# 2  Charlie   NaN        Delhi      M    charlie@example  2021-07-20
# 3    David  22.0       Mumbai      M  david@example.com  2019-11-12
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5    Alice  25.0     New York      F  alice@example.com  2021-05-01
# 6  Charlie   NaN        Delhi      M    charlie@example  2021-07-20

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  2021-05-01
# 1    Bob   30  Los Angeles      M    bob@example.com  2020-06-15
# 3  David   22       Mumbai      M  david@example.com  2019-11-12
# 5  Alice   25     New York      F  alice@example.com  2021-05-01

# %%
df2["Age Group"] = df2["Age"].apply(lambda x: "Adult" if x >= 25 else "Minor")
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com  2021-05-01     Adult
# 1    Bob   30  Los Angeles      M    bob@example.com  2020-06-15     Adult
# 3  David   22       Mumbai      M  david@example.com  2019-11-12     Minor
# 5  Alice   25     New York      F  alice@example.com  2021-05-01     Adult

# %%
def isminor(x):
    return "Adult" if x >= 25 else "Minor"
df2["Age Group"] = df2["Age"].apply(isminor)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com  2021-05-01     Adult
# 1    Bob   30  Los Angeles      M    bob@example.com  2020-06-15     Adult
# 3  David   22       Mumbai      M  david@example.com  2019-11-12     Minor
# 5  Alice   25     New York      F  alice@example.com  2021-05-01     Adult

# %%
gender_map = {"M": "Male", "F": "Female"}
df2["Gender"] = df2["Gender"].map(gender_map)

# %%
df2
# Out:
#     Name  Age         City  Gender              Email   Join Date Age Group
# 0  Alice   25     New York  Female  alice@example.com  2021-05-01     Adult
# 1    Bob   30  Los Angeles    Male    bob@example.com  2020-06-15     Adult
# 3  David   22       Mumbai    Male  david@example.com  2019-11-12     Minor
# 5  Alice   25     New York  Female  alice@example.com  2021-05-01     Adult

# %%
df2["City"] = df2["City"].replace({"Los Angeles": "Delhi", "New York": "NY"})
df2
# Out:
#     Name  Age    City  Gender              Email   Join Date Age Group
# 0  Alice   25      NY  Female  alice@example.com  2021-05-01     Adult
# 1    Bob   30   Delhi    Male    bob@example.com  2020-06-15     Adult
# 3  David   22  Mumbai    Male  david@example.com  2019-11-12     Minor
# 5  Alice   25      NY  Female  alice@example.com  2021-05-01     Adult
