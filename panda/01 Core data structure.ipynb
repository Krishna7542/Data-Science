# %%
import pandas as pd

# %%
s = pd.Series([71,52,84,96,7,21,45,64])

# %%
s
# Out:
# 0    71
# 1    52
# 2    84
# 3    96
# 4     7
# 5    21
# 6    45
# 7    64
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([71,52,84,96,2,21,45,64], index =[ "krishna", "don", "king", "rajni","adarsh","krish", "sweety","tarun",])

# %%
s2
# Out:
# krishna    71
# don        52
# king       84
# rajni      96
# adarsh      2
# krish      21
# sweety     45
# tarun      64
# dtype: int64

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "London", "Paris"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')
